# %% [markdown]
# # Glass Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv')

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
x=df.drop_duplicates(inplace=True)

# %%
value_mapping = {1:0, 2:1, 3:2, 5:3, 6:4, 7:5}

# Use the replace() function to map the values in the column
df['Type'] = df['Type'].replace(value_mapping)

df['Type'].value_counts().reset_index()
# Out:
#    Type  count
# 0     1     76
# 1     0     69
# 2     5     29
# 3     2     17
# 4     3     13
# 5     4      9

# %%
cr=df.corr().transpose()

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(cr, annot=True, cmap='magma',cbar=False, fmt='f')
plt.xticks(rotation=45)
plt.title('Data Frame Correlation')
plt.show()

# %%
ds=df.describe().transpose()

# %%
ds.plot(kind='bar', figsize=(10, 6))
plt.title('Descriptive Statistics')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Na', kde=True)
plt.title('Na Distribution')
plt.xlabel('Na')
plt.ylabel('Count')
plt.show()

# %%
sns.scatterplot(data=df,x='Type',y='RI',hue='Type',palette='coolwarm')
plt.show()

# %%
columns = ["Na", "Mg", "Al", "Si", "K", "Ca", "Ba", "Fe"]
for col in columns:
    sns.scatterplot(data=df, x=col, y="RI")

# %%
sns.pairplot(data=df)
plt.show()

# %%
Na_Type=df.loc[df['Type'].value_counts(),'Na']
Na_Type.reset_index().rename(columns={'Na': 'Na weight percent in corresponding oxide','index':'Type Count'})
# Out:
#    Type Count  Na weight percent in corresponding oxide
# 0          76                                     13.44
# 1          69                                     13.31
# 2          29                                     13.08
# 3          17                                     14.36
# 4          13                                     12.86
# 5           9                                     13.00

# %%
Mg_Type=df.loc[df['Type'].value_counts(),'Mg']
Mg_Type.reset_index().rename(columns={'Mg': 'Mg weight percent in corresponding oxide','index':'Type Count'})
# Out:
#    Type Count  Mg weight percent in corresponding oxide
# 0          76                                      3.61
# 1          69                                      3.58
# 2          29                                      3.49
# 3          17                                      3.85
# 4          13                                      3.56
# 5           9                                      3.60

# %%
Al_Type=df.loc[df['Type'].value_counts(),'Al']
Al_Type.reset_index().rename(columns={'Al': 'Al weight percent in corresponding oxide','index':'Type Count'})
# Out:
#    Type Count  Al weight percent in corresponding oxide
# 0          76                                      1.54
# 1          69                                      0.82
# 2          29                                      1.28
# 3          17                                      0.89
# 4          13                                      1.27
# 5           9                                      1.36

# %%
Si_Type=df.loc[df['Type'].value_counts(),'Si']
Si_Type.reset_index().rename(columns={'Si': 'Si weight percent in corresponding oxide','index':'Type Count'})
# Out:
#    Type Count  Si weight percent in corresponding oxide
# 0          76                                     72.39
# 1          69                                     71.99
# 2          29                                     72.86
# 3          17                                     71.36
# 4          13                                     73.21
# 5           9                                     72.99

# %%
K_Type=df.loc[df['Type'].value_counts(),'K']
K_Type.reset_index().rename(columns={'K': 'K weight percent in corresponding oxide','index':'Type Count'})
# Out:
#    Type Count  K weight percent in corresponding oxide
# 0          76                                     0.66
# 1          69                                     0.12
# 2          29                                     0.60
# 3          17                                     0.15
# 4          13                                     0.54
# 5           9                                     0.57

# %%
Ca_Type=df.loc[df['Type'].value_counts().head(),'Ca']
Ca_Type.reset_index().rename(columns={'Ca': 'Ca weight percent in corresponding oxide','index':'Type Count'})
# Out:
#    Type Count  Ca weight percent in corresponding oxide
# 0          76                                      8.03
# 1          69                                     10.17
# 2          29                                      8.49
# 3          17                                      9.15
# 4          13                                      8.38

# %%
Ba_Type=df.loc[df['Type'].value_counts(),'Ba']
Ba_Type.reset_index().rename(columns={'Ba': 'Ba weight percent in corresponding oxide','index':'Type Count'})
# Out:
#    Type Count  Ba weight percent in corresponding oxide
# 0          76                                       0.0
# 1          69                                       0.0
# 2          29                                       0.0
# 3          17                                       0.0
# 4          13                                       0.0
# 5           9                                       0.0

# %%
Fe_Type=df.loc[df['Type'].value_counts(),'Fe']
Fe_Type.reset_index().rename(columns={'Fe': 'Fe weight percent in corresponding oxide','index':'Type Count'})
# Out:
#    Type Count  Fe weight percent in corresponding oxide
# 0          76                                      0.00
# 1          69                                      0.03
# 2          29                                      0.00
# 3          17                                      0.00
# 4          13                                      0.17
# 5           9                                      0.11

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x=df.iloc[:,:-1]
y=df['Type']

# %%
x.shape
# Out:
# (213, 9)

# %%
y.shape
# Out:
# (213,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=5)
x_train,x_val,y_train,y_val=train_test_split(x,y,test_size=0.15,random_state=5)

# %%
scale=StandardScaler()
x_train=scale.fit_transform(x_train)
x_val=scale.transform(x_val)
x_test=scale.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import svm
param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': [0.1, 1, 10]
}
svm_model = svm.SVC()
grid_search = GridSearchCV(svm_model, param_grid, cv=5)
grid_search.fit(x_train, y_train)
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# Best Score: 0.6686186186186186

# %%
svm_model=svm.SVC(C= 1, gamma= 0.1, kernel= 'rbf')
svm_model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2444\4076937556.py in <module>
# ----> 1 svm_model=svm.SVC(C= 1, gamma= 0.1, kernel= 'rbf')
#       2 svm_model.fit(x_train,y_train)
#
# NameError: name 'svm' is not defined

# %%
from sklearn.metrics import accuracy_score
y_pred_train=svm_model.predict(x_train)
y_pred_val=svm_model.predict(x_val)
print('accuracy of x_train = ',accuracy_score(y_train,y_pred_train))
print('accuracy of x_val = ',accuracy_score(y_val,y_pred_val))
# Out:
# accuracy of x_train =  0.7845303867403315
# accuracy of x_val =  0.8125

# %%
y_pred_test=svm_model.predict(x_test)
print('accuracy of x_test = ',accuracy_score(y_test,y_pred_test))
# Out:
# accuracy of x_test =  0.813953488372093

# %%
from sklearn.metrics import confusion_matrix
cn=confusion_matrix(y_test,y_pred_test)
sns.heatmap(cn,annot=True,cmap='Blues')
plt.show()

# %%
sns.scatterplot(x=y_test,y=y_pred_test,cmap='Reds')
plt.xlabel('y_test')
plt.ylabel('y_predict')
plt.show()

# %%
index = np.arange(len(y_test))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(index, y_test, c='blue', label='Actual')
ax.scatter(index, y_pred_test, c='red', label='Predicted')
ax.set_xlabel('Index')
ax.set_ylabel('Values')
ax.set_zlabel('Target')
ax.legend()
plt.show()
